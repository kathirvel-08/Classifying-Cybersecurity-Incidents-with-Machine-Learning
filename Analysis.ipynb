# %%
import pandas as pd

# %%
df=pd.read_csv('E:/Project/Project files/Microsoft/Data/cleaned_df.csv')
df.head()
# Out:
#    Unnamed: 0  AlertTitle            Category   IncidentGrade EntityType  \
# 0           0         813             Malware  BenignPositive       File
# 1           1          25              Impact  BenignPositive    Machine
# 2           2         444           Execution  BenignPositive    Machine
# 3           3        1233  SuspiciousActivity    TruePositive       File
# 4           4       58829        Exfiltration  BenignPositive       File
#
#   EvidenceRole  Sha256  IpAddress     Url  AccountUpn  ...  FileName  \
# 0      Related    1296     360606  160396      673934  ...      4132
# 1     Impacted  138268     360606  160396      673934  ...    289573
# 2     Impacted  138268     360606  160396      673934  ...    289573
# 3      Related  138268     360606  160396      673934  ...     97007
# 4     Impacted  138268     360606  160396      673934  ...     39978
#
#    FolderPath  OSFamily  OSVersion  CountryCode  State   City  Year  Month  \
# ...

# %%
df.drop(columns="Unnamed: 0",axis=1,inplace=True)

# %%
df.shape
# Out:
# (4602224, 25)

# %%
df.iloc[:,:15].head()
# Out:
#    AlertTitle            Category   IncidentGrade EntityType EvidenceRole  \
# 0         813             Malware  BenignPositive       File      Related
# 1          25              Impact  BenignPositive    Machine     Impacted
# 2         444           Execution  BenignPositive    Machine     Impacted
# 3        1233  SuspiciousActivity    TruePositive       File      Related
# 4       58829        Exfiltration  BenignPositive       File     Impacted
#
#    Sha256  IpAddress     Url  AccountUpn  AccountName  DeviceName  \
# 0    1296     360606  160396      673934       453297      153085
# 1  138268     360606  160396      673934       453297        3142
# 2  138268     360606  160396      673934       453297        4181
# 3  138268     360606  160396      673934       453297      153085
# 4  138268     360606  160396      673934       453297      153085
#
#    RegistryKey  RegistryValueName  RegistryValueData  ApplicationName
# ...

# %%
df.iloc[:,15:].head()
# Out:
#    FileName  FolderPath  OSFamily  OSVersion  CountryCode  State   City  Year  \
# 0      4132        4227         5         66          242   1445  10630  2024
# 1    289573      117668         5         66          242   1445  10630  2024
# 2    289573      117668         5         66          242   1445  10630  2024
# 3     97007        9177         5         66          242   1445  10630  2024
# 4     39978      114449         5         66          242   1445  10630  2024
#
#    Month  Day
# 0      6    6
# 1      6    3
# 2      6   13
# 3      6    8
# 4      6    9

# %% [markdown]
# # 1. Incident grade based categorical impact

# %%
import matplotlib.pyplot as plt
for category in df['IncidentGrade'].dropna().unique():
    frame = df[df['IncidentGrade'] == category]
    frame['Category'].value_counts().plot(kind='barh')
    plt.title(f'{category} Impact Count')
    plt.show()

# %% [markdown]
# # 2.Entity type based on Incident Grade

# %%
for category in df['IncidentGrade'].dropna().unique():
    frame = df[df['IncidentGrade'] == category]
    frame['EntityType'].value_counts().plot(kind='barh')
    plt.title(f'{category} Impact Count')
    plt.show()

# %% [markdown]
# # 3. Evidence Role as per Incident Grade

# %%
for category in df['IncidentGrade'].dropna().unique():
    frame = df[df['IncidentGrade'] == category]
    frame['EvidenceRole'].value_counts().plot(kind='barh')
    plt.title(f'{category} Impact Count')
    plt.show()

# %% [markdown]
# # 4. Incident Grade based on Year

# %%
for category in df['IncidentGrade'].dropna().unique():
    frame = df[df['IncidentGrade'] == category]
    frame['Year'].value_counts().plot(kind='barh')
    plt.title(f'{category} Impact Count')
    plt.show()

# %% [markdown]
# # 5. Incident Grade based on month

# %%
for category in df['IncidentGrade'].dropna().unique():
    frame = df[df['IncidentGrade'] == category]
    frame['Month'].value_counts().plot(kind='barh')
    plt.title(f'{category} Impact Count')
    plt.show()

# %% [markdown]
# # 6. Incident Grade based on Os

# %%
for category in df['IncidentGrade'].dropna().unique():
    frame = df[df['IncidentGrade'] == category]
    frame['OSFamily'].value_counts().plot(kind='barh')
    plt.title(f'{category} Impact Count')
    plt.show()

# %% [markdown]
# # 7. Incident Grade over all distribution

# %%
df['IncidentGrade'].value_counts().plot(kind='pie',autopct='%1.2f%%')
plt.title("Incident grade impact")
# Out:
# Text(0.5, 1.0, 'Incident grade impact')
